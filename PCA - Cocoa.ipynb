# %%
import TickLoader

import numpy as np
import pandas as pd
import datetime as dt
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
from IPython import get_ipython
import matplotlib.mlab as mlab
import itertools

# %%
data=pd.read_csv('cocoaData20180223.csv',index_col=0)
data = data.drop(['Z8 Arb','US_KZ','UK_KZ','KZ_Box','USH8','UKH8'],axis=1)
data = data.dropna(axis=0, how='any')
data.head(3)
# Out:
#                USK8  USN8  USU8  USZ8  UKK8  UKN8  UKU8  UKZ8
# 1/2/2018 3:45  1901  1909  1924  1950  1906  1931  1951  1981
# 1/2/2018 3:46  1899  1906  1922  1947  1904  1929  1948  1979
# 1/2/2018 3:47  1899  1906  1922  1947  1904  1929  1949  1980

# %%
# Out:
# array([[ 5.1,  3.5,  1.4,  0.2],
#        [ 4.9,  3. ,  1.4,  0.2],
#        [ 4.7,  3.2,  1.3,  0.2],
#        [ 4.6,  3.1,  1.5,  0.2],
#        [ 5. ,  3.6,  1.4,  0.2],
#        [ 5.4,  3.9,  1.7,  0.4],
#        [ 4.6,  3.4,  1.4,  0.3],
#        [ 5. ,  3.4,  1.5,  0.2],
#        [ 4.4,  2.9,  1.4,  0.2],
#        [ 4.9,  3.1,  1.5,  0.1],
#        [ 5.4,  3.7,  1.5,  0.2],
#        [ 4.8,  3.4,  1.6,  0.2],
#        [ 4.8,  3. ,  1.4,  0.1],
#        [ 4.3,  3. ,  1.1,  0.1],
#        [ 5.8,  4. ,  1.2,  0.2],
#        [ 5.7,  4.4,  1.5,  0.4],
#        [ 5.4,  3.9,  1.3,  0.4],
#        [ 5.1,  3.5,  1.4,  0.3],
#        [ 5.7,  3.8,  1.7,  0.3],
#        [ 5.1,  3.8,  1.5,  0.3],
#        [ 5.4,  3.4,  1.7,  0.2],
#        [ 5.1,  3.7,  1.5,  0.4],
#        [ 4.6,  3.6,  1. ,  0.2],
#        [ 5.1,  3.3,  1.7,  0.5],
#        [ 4.8,  3.4,  1.9,  0.2],
#        [ 5. ,  3. ,  1.6,  0.2],
#        [ 5. ,  3.4,  1.6,  0.4],
#        [ 5.2,  3.5,  1.5,  0.2],
# ...

# %%
#PCA

import numpy as np
from sklearn.decomposition import PCA

X = data.diff()
X = X.dropna(axis=0, how='any')
pca = PCA()
pca.fit(X)
PCA(copy=True, iterated_power='auto', random_state=None,
  svd_solver='auto', tol=0.0, whiten=False)


print(pca.explained_variance_ratio_)  
 

plt.plot(pca.explained_variance_ratio_)
plt.show()

print(pca.components_)

for i in pca.components_:
    plt.plot(i)
    plt.show()#PCA from book
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.datasets import load_iris

data = load_iris()


data.data
# Out:
# [ 0.87722032  0.0764191   0.01656223  0.0113975   0.00828465  0.00710191
#   0.00189114  0.00112315]
# [[  3.60804600e-01   3.58698250e-01   3.57525503e-01   3.57334321e-01
#     3.47784045e-01   3.48782151e-01   3.49129515e-01   3.48064871e-01]
#  [  3.37585831e-01   3.47244141e-01   3.49484072e-01   3.57500007e-01
#    -3.18283903e-01  -3.52603449e-01  -3.73900382e-01  -3.87397225e-01]
#  [  5.25445849e-01  -4.88866594e-01   4.79282470e-01  -5.04983702e-01
#    -5.37156746e-04  -2.08060622e-03  -1.37322629e-02   1.64178012e-03]
#  [ -1.41097377e-02  -1.25925949e-02  -2.44389794e-02  -2.03392924e-02
#     7.27643320e-01   2.30010039e-01  -3.26459513e-01  -5.56494527e-01]
#  [  6.05220078e-03  -4.51508359e-03   3.63637335e-03  -1.34032632e-03
#    -4.19958579e-01   5.54537963e-01   4.32338537e-01  -5.73701834e-01]
#  [  7.78117228e-03  -3.13252775e-03  -3.42300214e-03  -8.92629282e-03
#     2.67828818e-01  -6.27374335e-01   6.66758399e-01  -2.99901065e-01]
# ...

# %%
#PCA from book
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.datasets import load_iris

data = load_iris()
Y=data.target
X=data.data
pca=PCA(n_components=2)

# reduced data:
reduced_X=pca.fit_transform(X)

#plot reduced data
red_x, red_y = [], []
blue_x, blue_y = [], []
green_x, green_y = [], []

for i in range(len(reduced_X)):
    if Y[i] == 0:
        red_x.append(reduced_X[i][0])
        red_y.append(reduced_X[i][1])
    elif Y[i] == 1:
        blue_x.append(reduced_X[i][0])
        blue_y.append(reduced_X[i][1])
    else:
        green_x.append(reduced_X[i][0])
        green_y.append(reduced_X[i][1])

plt.scatter(red_x, red_y, c='r', marker='x')
plt.scatter(blue_x, blue_y, c='b', marker='D')
plt.scatter(green_x, green_y, c='g', marker='.')
plt.show()
